# %%
#Importera pandas
import pandas as pd
import numpy as np
#Läs in fil
skatt_df = pd.read_csv('miljo.csv')
skatt_df
# Out:
#     Year    Tax
# 0   2011  44141
# 1   2012  44714
# 2   2013  45228
# 3   2014  45935
# 4   2015  46676
# 5   2016  48468
# 6   2017  50051
# 7   2018  52209
# 8   2019  52296
# 9   2020  50978
# 10  2021  52204

# %%
#Få fram de första fem raderna
skatt_df.head()
# Out:
#    Year    Tax
# 0  2011  44141
# 1  2012  44714
# 2  2013  45228
# 3  2014  45935
# 4  2015  46676

# %%
#skriv ut stapeldiagram som visar miljöskatten per år
skatt_df.plot.bar(x='Year', title= 'Miljöskatt genom åren')
# Out:
# <Axes: title={'center': 'Miljöskatt genom åren'}, xlabel='Year'>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Läs in CSV-filen
df = pd.read_csv('miljo.csv')

# Skapa ett linjediagram
df.plot(x='Year', y=' Tax', kind='line', marker='o')

# Visa diagrammet
plt.show()

# %%
# Välj de två år du vill jämföra
år1 = input('Skriv ett år du vill kolla på (2011-2021): ')
år2 = input('Skriv året du vill jämföra det med (2011-2021): ')
print(f'{år1} och {år2}')

# Filtrera DataFrame för att få endast de två åren
selected_years = df[df['Year'].isin([int(år1), int(år2)])]

# Skapa ett stapeldiagram
selected_years.plot(x='Year', y=' Tax', kind='bar', legend=False)

# Ange diagramtitel och etiketter
plt.title(f'Jämförelse av miljöskatt mellan {år1} och {år2}')
plt.xlabel('År')
plt.ylabel('Miljöskatt')

# Visa diagrammet
plt.show()
# Out:
# 2011 och 2020
